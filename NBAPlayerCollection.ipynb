# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver

import string
import datetime
import time
import csv
import ast
import import_ipynb
import NBAInjuryAnalysis
import NBAPlayerAnalysis
import NBANetRatingAnalysis
# Out:
# importing Jupyter notebook from NBAInjuryAnalysis.ipynb
# importing Jupyter notebook from NBAPlayerAnalysis.ipynb
# importing Jupyter notebook from NBANetRatingAnalysis.ipynb

# %%
# global variables
# %store -r playersToIds
# %store -r idsToPlayers
# %store -r datesDict
# %store -r playoffDates
# %store -r statsNBAMap
# %store -r apd

# %%
allPlayerData = {}
errorPlayers = set()

# %%
def collectPlayerData(playerName):
    playerData = {}
    playerData.update(NBAInjuryAnalysis.collectInjuryData(playerName))
    print('one')
    playerData.update(NBANetRatingAnalysis.collectNetRatings(playerName))
    print('two')
    playerData.update(NBAPlayerAnalysis.collectPlayerHistory(playerName))
    print('three')
    return playerData

def do2020():
    url = "https://www.basketball-reference.com/leagues/NBA_2020_totals.html"
    html = urlopen(url)
    soup = BeautifulSoup(html, features="lxml")
    players = soup.find('tbody').findAll('tr')
    for i in range(0, 50):
        player = players[i]
        if player['class'] == ["thead"]:
            continue
        playerName = player.find('a').text
        if playerName not in allPlayerData:
            print(playerName)
            try:
                playerData = collectPlayerData(playerName)
                allPlayerData[playerName] = playerData
            except KeyboardInterrupt:
                print('keyboard interrupt')
                break
            except Exception as e:
                print("error:", playerName)
                print(e)

# %%
do2020()
# Out:
# Marvin Bagley III
# one
# two
# three
# Mo Bamba
# one
# two
# three

# %%
print(allPlayerData.keys())
# Out:
# dict_keys(['Steven Adams', 'Bam Adebayo', 'Nickeil Alexander-Walker', 'Grayson Allen', 'Jarrett Allen', 'Kadeem Allen', 'Al-Farouq Aminu', 'Justin Anderson', 'Kyle Anderson', 'Giannis Antetokounmpo', 'Kostas Antetokounmpo', 'Thanasis Antetokounmpo', 'Carmelo Anthony', 'Ryan Arcidiacono', 'Trevor Ariza', 'Deandre Ayton', 'Ryan Anderson', 'OG Anunoby', 'D.J. Augustin', 'Lonzo Ball', 'J.J. Barea', 'Harrison Barnes', 'Dwayne Bacon', 'RJ Barrett', 'Will Barton', 'Keita Bates-Diop', 'Nicolas Batum', 'Aron Baynes', 'Kent Bazemore', 'Darius Bazley', 'Bradley Beal', 'Malik Beasley', 'Marco Belinelli', 'Jordan Bell', 'Dragan Bender', 'LaMarcus Aldridge', "DeAndre' Bembry", 'Marvin Bagley III', 'Mo Bamba'])

# %%
allPlayerData
# Out:
# {'Steven Adams': {'InjResp': (4.595454545454545,
#    {'2014-15': [[7.3,
#       [['Charlotte Hornets', '.459'],
#        ['Chicago Bulls', '.609'],
#        ['Dallas Mavericks', '.631'],
#        ['Denver Nuggets', '.349'],
#        ['Indiana Pacers', '.452'],
#        ['Los Angeles Lakers', '.258'],
#        ['Memphis Grizzlies', '.710'],
#        ['Philadelphia 76ers', '.222'],
#        ['Phoenix Suns', '.516'],
#        ['Portland Trail Blazers', '.672'],
#        ['Toronto Raptors', '.603']],
#       datetime.datetime(2015, 2, 9, 0, 0),
#       datetime.datetime(2015, 3, 8, 0, 0),
#       12]],
#     '2016-17': [[-13.6,
#       [['Golden State Warriors', '.844'],
#        ['LA Clippers', '.652'],
#        ['Utah Jazz', '.630']],
#       datetime.datetime(2017, 1, 16, 0, 0),
#       datetime.datetime(2017, 1, 23, 0, 0),
#       3]],
#     '2017-18': [[9.6,
#       [['Chicago Bulls', '.231'],
#        ['Dallas Mavericks', '.125'],
#        ['LA Clippers', '.357'],
# ...

# %%
w = csv.writer(open("0output.csv", "w"))
for key, val in allPlayerData.items():
    w.writerow([key, val])

# %%
with open('0output.csv', mode='r') as infile:
    reader = csv.reader(infile)
    with open('0reader.csv', mode='w') as outfile:
        writer = csv.writer(outfile)
        mydict = {rows[0]:rows[1] for rows in reader}

for name in mydict:
    val = mydict[name]
    mydict[name] = eval(val)

allPlayerData = mydict
allPlayerData.keys()
# Out:
# dict_keys(['Steven Adams', 'Bam Adebayo', 'Nickeil Alexander-Walker', 'Grayson Allen', 'Jarrett Allen', 'Kadeem Allen', 'Al-Farouq Aminu', 'Justin Anderson', 'Kyle Anderson', 'Giannis Antetokounmpo', 'Kostas Antetokounmpo', 'Thanasis Antetokounmpo', 'Carmelo Anthony', 'Ryan Arcidiacono', 'Trevor Ariza', 'Deandre Ayton', 'Ryan Anderson', 'OG Anunoby', 'D.J. Augustin', 'Lonzo Ball', 'J.J. Barea', 'Harrison Barnes', 'Dwayne Bacon', 'RJ Barrett', 'Will Barton', 'Keita Bates-Diop', 'Nicolas Batum', 'Aron Baynes', 'Kent Bazemore', 'Darius Bazley', 'Bradley Beal', 'Malik Beasley', 'Marco Belinelli', 'Jordan Bell', 'Dragan Bender', 'LaMarcus Aldridge', "DeAndre' Bembry", 'Marvin Bagley III', 'Mo Bamba'])

# %%
# collectPlayerData("Ma")
