# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
# NBA season we will be analyzing
year = 2020
# URL page we will scraping (see image above)
url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html".format(year)
# this is the HTML from the given URL
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
# use getText()to extract the text we need into a list
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
headers = headers[1:]
headers
# Out:
# ['Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
# avoid the first header row
rows = soup.findAll('tr')[1:]
player_stats = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]

# %%
stats = pd.DataFrame(player_stats, columns = headers)
stats.head(10)
# Out:
#                      Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  \
# 0              Steven Adams   C  26  OKC  48  48  27.0  4.4   7.6  .585  ...
# 1               Bam Adebayo  PF  22  MIA  53  53  34.6  6.2  10.7  .582  ...
# 2         LaMarcus Aldridge   C  34  SAS  50  50  33.2  7.4  14.9  .501  ...
# 3  Nickeil Alexander-Walker  SG  21  NOP  41   0  12.2  1.9   5.5  .339  ...
# 4             Grayson Allen  SG  24  MEM  30   0  16.6  2.6   5.9  .449  ...
# 5             Jarrett Allen   C  21  BRK  52  48  26.7  4.3   6.8  .644  ...
# 6              Kadeem Allen  SG  27  NYK  10   0  11.7  1.9   4.4  .432  ...
# 7           Al-Farouq Aminu  PF  29  ORL  18   2  21.1  1.4   4.8  .291  ...
# 8           Justin Anderson  SF  26  BRK   3   0   5.7  0.3   2.0  .167  ...
# 9             Kyle Anderson  PF  26  MEM  47   8  17.9  2.2   4.4  .493  ...
#
#     FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  .592  3.3  5.9   9.3  2.6  0.7  1.1  1.5  2.0  10.7
# 1  .683  2.6  7.8  10.4  4.9  1.2  1.2  2.7  2.4  16.0
# 2  .830  2.0  5.6   7.6  2.4  0.6  1.6  1.4  2.4  19.1
# 3  .607  0.2  1.8   2.0  1.8  0.3  0.2  1.0  1.1   5.1
# 4  .857  0.2  2.0   2.2  1.4  0.2  0.0  0.8  1.2   7.4
# 5  .626  3.1  6.5   9.6  1.4  0.6  1.5  1.1  2.4  11.1
# 6  .636  0.2  0.7   0.9  2.1  0.5  0.2  0.8  0.7   5.0
# 7  .655  1.3  3.5   4.8  1.2  1.0  0.4  0.9  1.5   4.3
# 8  .500  0.0  0.7   0.7  0.0  0.0  0.3  0.0  0.7   1.0
# 9  .648  0.9  3.1   4.0  2.2  0.7  0.5  0.9  1.5   5.3
#
# [10 rows x 29 columns]
